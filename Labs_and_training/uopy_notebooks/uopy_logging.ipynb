# %% [markdown]
# <a id='main'></a>
# ![logo](img/logo.png)

# %% [markdown]
# ## Server Logging for uopy
#
# Since uopy ( UniObjects for Python ) utilizes the same connection mechinism as the other Rocket UniObjects Clients, the all share the same tools/methods for turning on Server Side Logging.
#
#
# ### Turn on Windows UniRPC logging for Rocket U2 UniVerse or UniData Server
#
# For customers using the Rocket Customer Portal, the following KB will help:
#
# Article Number	000013980
#
# Title	How to start the Windows UniRPC Service using the debug level and timeout parameters in the Command mode
#
#
# #### For those who do not have access to the Customer Portal, the following Youtube video covers the same information.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('USjOty7-xtI', width=800, height=300)

# %% [markdown]
# ## Turn on U2 UniObjects (UO) Server Logging
#
#
# In te customer portal, there is the following KB item:
#
# Article Number	000014559
#
# Title	How to turn on the U2 UniObjects server log based on a specific service name
#
#
# Rocket's UniObjects for Python (uopy) is one of many UniObject client tools provided by Rocket Software.

# %%
YouTubeVideo('_rI2HVEiMW4', width=800, height=300)

# %% [markdown]
# ## U2 UOPY Client Logging for Python
#
#
# Specific to the uopy Client, the following video shows how to turn on logging on the client.

# %%
YouTubeVideo('l5OlNdyN1Bk', width=800, height=300)
